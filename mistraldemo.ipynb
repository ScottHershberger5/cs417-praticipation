# %% [markdown]
# <a href="https://colab.research.google.com/github/ScottHershberger5/cs417-praticipation/blob/main/mistraldemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
# !curl -LsSf https://mistral.ai/vibe/install.sh | bash
# Out:
# ██████████████████░░
# ██████████████████░░
# ████  ██████  ████░░
# ████    ██    ████░░
# ████          ████░░
# ████  ██  ██  ████░░
# ██      ██      ██░░
# ██████████████████░░
# ██████████████████░░
#
# Starting Mistral Vibe installation...
#
# [INFO] Detected Linux platform
# [INFO] uv is already installed: uv 0.11.3 (x86_64-unknown-linux-gnu)
# [INFO] Installing mistral-vibe from GitHub repository using uv...
# Resolved 91 packages in 1.01s
# Prepared 91 packages in 1.00s
# Installed 91 packages in 133ms
#  + agent-client-protocol==0.9.0
#  + annotated-types==0.7.0
#  + anyio==4.13.0
#  + attrs==26.1.0
#  + beautifulsoup4==4.14.3
#  + cachetools==7.0.6
#  + certifi==2026.4.22
#  + cffi==2.0.0
#  + charset-normalizer==3.4.7
#  + click==8.3.2
#  + cryptography==46.0.3
#  + eval-type-backport==0.3.1
#  + gitdb==4.0.12
#  + gitpython==3.1.47
#  + giturlparse==0.14.0
#  + google-auth==2.49.2
#  + googleapis-common-protos==1.74.0
#  + h11==0.16.0
#  + httpcore==1.0.9
# ...
