# %% [markdown]
# <a href="https://colab.research.google.com/github/ScottHershberger5/cs417-praticipation/blob/main/participation_April_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random #prints a random output everytime

for i in range(0,10):
  random_num = random.randint(1,10)
  print(random_num)
# Out:
# 10
# 6
# 5
# 3
# 3
# 1
# 6
# 9
# 8
# 10

# %%
import random

for i in range(0,10):
  random.seed(9) # makes the random number the same each time
  random_num = random.randint(1,10)
  print(random_num)
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8

# %%
import random #DIFFERENT SEED

for i in range(0,10):
  random.seed(3) # makes the random number the same each time
  random_num = random.randint(1,10)
  print(random_num)
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
